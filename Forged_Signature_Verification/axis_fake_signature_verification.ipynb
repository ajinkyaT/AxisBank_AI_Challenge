# %% [markdown]
# ## Installing PyTorch and Pillow == 0.4

# %%
from os import path
from wheel.pep425tags import get_abbr_impl, get_impl_ver, get_abi_tag
platform = '{}{}-{}'.format(get_abbr_impl(), get_impl_ver(), get_abi_tag())

accelerator = 'cu80' if path.exists('/opt/bin/nvidia-smi') else 'cpu'

# !pip install -q http://download.pytorch.org/whl/{accelerator}/torch-0.4.0-{platform}-linux_x86_64.whl torchvision
import torch
print(torch.__version__)
print(torch.cuda.is_available())
# Out:
# 0.4.0
# True

# %%
# !pip install Pillow==4.0.0
# Out:
# Collecting Pillow==4.0.0
#   Using cached https://files.pythonhosted.org/packages/37/e8/b3fbf87b0188d22246678f8cd61e23e31caa1769ebc06f1664e2e5fe8a17/Pillow-4.0.0-cp36-cp36m-manylinux1_x86_64.whl
# Requirement already satisfied: olefile in /usr/local/lib/python3.6/dist-packages (from Pillow==4.0.0) (0.46)
# torchvision 0.2.1 has requirement pillow>=4.1.1, but you'll have pillow 4.0.0 which is incompatible.
# Installing collected packages: Pillow
#   Found existing installation: Pillow 5.3.0
#     Uninstalling Pillow-5.3.0:
#       Successfully uninstalled Pillow-5.3.0
# Successfully installed Pillow-4.0.0

# %% [markdown]
# ## Imports
# All the imports are defined here

# %%
# %matplotlib inline
import os
import torchvision
import torchvision.datasets as dset
import torchvision.transforms as transforms
from torch.utils.data import DataLoader,Dataset
import matplotlib.pyplot as plt
import torchvision.utils
import numpy as np
import random
from PIL import Image
import torch
from torch.autograd import Variable
import PIL.ImageOps    
import torch.nn as nn
from torch import optim
import torch.nn.functional as F

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
# !ls '/content/drive/My Drive/Colab Notebooks/axis_data/processed_dataset'
# Out:
# forged	testing  training

# %% [markdown]
# ## Helper functions
# Set of helper functions

# %%
def imshow(img,text=None,should_save=False):
    npimg = img.numpy()
    plt.axis("off")
    if text:
        plt.text(75, 8, text, style='italic',fontweight='bold',
            bbox={'facecolor':'white', 'alpha':0.8, 'pad':10})
    plt.imshow(np.transpose(npimg, (1, 2, 0)))
    plt.show()    

def show_plot(iteration,loss):
    plt.plot(iteration,loss)
    plt.show()

# %% [markdown]
# ## Configuration Class
# A simple class to manage configuration

# %%
class Config():
    training_dir = "/content/drive/My Drive/Colab Notebooks/axis_data/processed_dataset/training/"
    testing_dir = "/content/drive/My Drive/Colab Notebooks/axis_data/processed_dataset/testing/"
    train_batch_size = 64
    train_number_epochs = 500

# %% [markdown]
# ## Custom Dataset Class
# This dataset generates a pair of images. 0 for geniune pair and 1 for imposter pair

# %%
class SiameseNetworkDataset(Dataset):
    
    def __init__(self,imageFolderDataset,transform=None,should_invert=True):
        self.imageFolderDataset = imageFolderDataset    
        self.transform = transform
        self.should_invert = should_invert
        
    def __getitem__(self,index):
        img0_tuple = random.choice(self.imageFolderDataset.imgs)
        #we need to make sure approx 50% of images are in the same class
        should_get_same_class = random.randint(0,1) 
        if should_get_same_class:
            while True:
                #keep looping till the same class image is found
                img1_tuple = random.choice(self.imageFolderDataset.imgs) 
                if img0_tuple[1]==img1_tuple[1]:
                    break
        else:
            while True:
                #keep looping till a different class image is found
                
                img1_tuple = random.choice(self.imageFolderDataset.imgs) 
                if img0_tuple[1] !=img1_tuple[1]:
                    break

        img0 = Image.open(img0_tuple[0])
        img1 = Image.open(img1_tuple[0])
        img0 = img0.convert("L")
        img1 = img1.convert("L")
        
        if self.should_invert:
            img0 = PIL.ImageOps.invert(img0)
            img1 = PIL.ImageOps.invert(img1)

        if self.transform is not None:
            img0 = self.transform(img0)
            img1 = self.transform(img1)
        
        return img0, img1 , torch.from_numpy(np.array([int(img1_tuple[1]!=img0_tuple[1])],dtype=np.float32))
    
    def __len__(self):
        return len(self.imageFolderDataset.imgs)

# %% [markdown]
# ## Using Image Folder Dataset

# %%
folder_dataset = dset.ImageFolder(root=Config.training_dir)

# %%
siamese_dataset = SiameseNetworkDataset(imageFolderDataset=folder_dataset,
                                        transform=transforms.Compose([transforms.Resize((100,100)),
                                                                      transforms.ToTensor()
                                                                      ])
                                       ,should_invert=False)

# %% [markdown]
# ## Visualising some of the data
# The top row and the bottom row of any column is one pair. The 0s and 1s correspond to the column of the image. 1 indiciates dissimilar, and 0 indicates similar.

# %%
vis_dataloader = DataLoader(siamese_dataset,
                        shuffle=True,
                        num_workers=8,
                        batch_size=8)
dataiter = iter(vis_dataloader)


example_batch = next(dataiter)
concatenated = torch.cat((example_batch[0],example_batch[1]),0)
imshow(torchvision.utils.make_grid(concatenated))
print(example_batch[2].numpy())
# Out:
# [[0.]
#  [1.]
#  [1.]
#  [1.]
#  [0.]
#  [1.]
#  [0.]
#  [0.]]

# %% [markdown]
# ## Neural Net Definition
# We will use a standard convolutional neural network
#
# Its architecture might look like below,
#
# ![](https://res.mdpi.com/symmetry/symmetry-10-00385/article_deploy/html/images/symmetry-10-00385-g001.png)

# %%
class SiameseNetwork(nn.Module):
    def __init__(self):
        super(SiameseNetwork, self).__init__()
        self.cnn1 = nn.Sequential(
            nn.ReflectionPad2d(1),
            nn.Conv2d(1, 128, kernel_size=3),
            nn.ReLU(inplace=True),
            nn.BatchNorm2d(128),
            
            nn.ReflectionPad2d(1),
            nn.Conv2d(128, 64, kernel_size=3),
            nn.ReLU(inplace=True),
            nn.BatchNorm2d(64),
            
            nn.ReflectionPad2d(1),
            nn.Conv2d(64, 32, kernel_size=3),
            nn.ReLU(inplace=True),
            nn.BatchNorm2d(32),

            nn.ReflectionPad2d(1),
            nn.Conv2d(32, 16, kernel_size=3),
            nn.ReLU(inplace=True),
            nn.BatchNorm2d(16),
            
            nn.ReflectionPad2d(1),
            nn.Conv2d(16, 8, kernel_size=3),
            nn.ReLU(inplace=True),
            nn.BatchNorm2d(8),


        )

        self.fc1 = nn.Sequential(
            nn.Linear(8*100*100, 500),
            nn.ReLU(inplace=True),

            nn.Linear(500, 500),
            nn.ReLU(inplace=True),

            nn.Linear(500, 5))

    def forward_once(self, x):
        output = self.cnn1(x)
        output = output.view(output.size()[0], -1)
        output = self.fc1(output)
        return output

    def forward(self, input1, input2):
        output1 = self.forward_once(input1)
        output2 = self.forward_once(input2)
        return output1, output2

# %% [markdown]
# ## Contrastive Loss

# %%
class ContrastiveLoss(torch.nn.Module):
    """
    Contrastive loss function.
    Based on: http://yann.lecun.com/exdb/publis/pdf/hadsell-chopra-lecun-06.pdf
    """

    def __init__(self, margin=2.0):
        super(ContrastiveLoss, self).__init__()
        self.margin = margin

    def forward(self, output1, output2, label):
        euclidean_distance = F.pairwise_distance(output1, output2)
        loss_contrastive = torch.mean((1-label) * torch.pow(euclidean_distance, 2) +
                                      (label) * torch.pow(torch.clamp(self.margin - euclidean_distance, min=0.0), 2))


        return loss_contrastive

# %% [markdown]
# ## Training Time!

# %%
train_dataloader = DataLoader(siamese_dataset,
                        shuffle=True,
                        num_workers=8,
                        batch_size=Config.train_batch_size)

# %%
net = SiameseNetwork().cuda()
criterion = ContrastiveLoss()
optimizer = optim.Adam(net.parameters(),lr = 0.001)

# %%
counter = []
loss_history = [] 
iteration_number= 0

# %%
for epoch in range(0,Config.train_number_epochs):
    for i, data in enumerate(train_dataloader,0):
        img0, img1 , label = data
        img0, img1 , label = img0.cuda(), img1.cuda() , label.cuda()
        optimizer.zero_grad()
        output1,output2 = net(img0,img1)
        loss_contrastive = criterion(output1,output2,label)
        loss_contrastive.backward()
        optimizer.step()
        if i %10 == 0 :
            print("Epoch number {}\n Current loss {}\n".format(epoch,loss_contrastive.item()))
            iteration_number +=10
            counter.append(iteration_number)
            loss_history.append(loss_contrastive.item())
show_plot(counter,loss_history)
# Out:
# Epoch number 0
#  Current loss 1.8971645832061768
#
# Epoch number 1
#  Current loss 1.5417168140411377
#
# Epoch number 2
#  Current loss 1.3705109357833862
#
# Epoch number 3
#  Current loss 1.2173497676849365
#
# Epoch number 4
#  Current loss 1.18314528465271
#
# Epoch number 5
#  Current loss 1.2296886444091797
#
# Epoch number 6
#  Current loss 1.2389476299285889
#
# Epoch number 7
#  Current loss 1.2234059572219849
#
# Epoch number 8
#  Current loss 1.1456890106201172
#
# Epoch number 9
#  Current loss 1.1721255779266357
#
# Epoch number 10
#  Current loss 1.1411502361297607
#
# Epoch number 11
#  Current loss 1.267268180847168
#
# Epoch number 12
#  Current loss 1.1481679677963257
#
# Epoch number 13
#  Current loss 1.2315616607666016
#
# Epoch number 14
#  Current loss 1.138778805732727
#
# Epoch number 15
#  Current loss 1.1035079956054688
#
# Epoch number 16
#  Current loss 1.159496545791626
#
# Epoch number 17
#  Current loss 1.2460486888885498
#
# Epoch number 18
#  Current loss 1.2197586297988892
#
# Epoch number 19
#  Current loss 1.1736094951629639
#
# Epoch number 20
#  Current loss 1.1401275396347046
#
# Epoch number 21
#  Current loss 1.166046380996704
#
# Epoch number 22
#  Current loss 1.0842519998550415
#
# Epoch number 23
#  Current loss 1.2009469270706177
#
# Epoch number 24
#  Current loss 1.098440170288086
#
# Epoch number 25
#  Current loss 1.1309573650360107
#
# Epoch number 26
#  Current loss 1.1907323598861694
#
# Epoch number 27
#  Current loss 1.2744001150131226
#
# Epoch number 28
#  Current loss 1.1423808336257935
#
# Epoch number 29
#  Current loss 1.1687194108963013
#
# Epoch number 30
#  Current loss 1.2120577096939087
#
# Epoch number 31
#  Current loss 1.1830507516860962
#
# Epoch number 32
#  Current loss 1.1244516372680664
#
# Epoch number 33
#  Current loss 1.0868053436279297
#
# Epoch number 34
#  Current loss 1.2258127927780151
#
# Epoch number 35
#  Current loss 1.0920201539993286
#
# Epoch number 36
#  Current loss 1.2947404384613037
#
# Epoch number 37
#  Current loss 1.2033109664916992
#
# Epoch number 38
#  Current loss 1.1365764141082764
#
# Epoch number 39
#  Current loss 1.1508638858795166
#
# Epoch number 40
#  Current loss 1.1165108680725098
#
# Epoch number 41
#  Current loss 1.1066148281097412
#
# Epoch number 42
#  Current loss 1.1619482040405273
#
# Epoch number 43
#  Current loss 1.1320042610168457
#
# Epoch number 44
#  Current loss 1.1852248907089233
#
# Epoch number 45
#  Current loss 1.1523274183273315
#
# Epoch number 46
#  Current loss 1.1122262477874756
#
# Epoch number 47
#  Current loss 1.216679573059082
#
# Epoch number 48
#  Current loss 1.231540322303772
#
# Epoch number 49
#  Current loss 1.1749122142791748
#
# Epoch number 50
#  Current loss 1.1575746536254883
#
# Epoch number 51
#  Current loss 1.1429470777511597
#
# Epoch number 52
#  Current loss 1.162796974182129
#
# Epoch number 53
#  Current loss 1.17586350440979
#
# Epoch number 54
#  Current loss 1.1458722352981567
#
# Epoch number 55
#  Current loss 1.157912254333496
#
# Epoch number 56
#  Current loss 1.0829280614852905
#
# Epoch number 57
#  Current loss 1.2452750205993652
#
# Epoch number 58
#  Current loss 1.1170846223831177
#
# Epoch number 59
#  Current loss 1.1280370950698853
#
# Epoch number 60
#  Current loss 1.1549878120422363
#
# Epoch number 61
#  Current loss 1.1135540008544922
#
# Epoch number 62
#  Current loss 1.1901389360427856
#
# Epoch number 63
#  Current loss 1.1857315301895142
#
# Epoch number 64
#  Current loss 1.1996055841445923
#
# Epoch number 65
#  Current loss 1.1132845878601074
#
# Epoch number 66
#  Current loss 1.2049083709716797
#
# Epoch number 67
#  Current loss 1.1526429653167725
#
# Epoch number 68
#  Current loss 1.0581016540527344
#
# Epoch number 69
#  Current loss 1.150369644165039
#
# Epoch number 70
#  Current loss 1.067336082458496
#
# Epoch number 71
#  Current loss 1.1893256902694702
#
# Epoch number 72
#  Current loss 1.1484485864639282
#
# Epoch number 73
#  Current loss 1.1554367542266846
#
# Epoch number 74
#  Current loss 1.113027572631836
#
# Epoch number 75
#  Current loss 1.0710363388061523
#
# Epoch number 76
#  Current loss 1.2316749095916748
#
# Epoch number 77
#  Current loss 1.1504218578338623
#
# Epoch number 78
#  Current loss 1.1434911489486694
#
# Epoch number 79
#  Current loss 1.1214920282363892
#
# Epoch number 80
#  Current loss 1.044865369796753
#
# Epoch number 81
#  Current loss 1.1127183437347412
#
# Epoch number 82
#  Current loss 1.149385690689087
#
# Epoch number 83
#  Current loss 1.1269505023956299
#
# Epoch number 84
#  Current loss 1.1108732223510742
#
# Epoch number 85
#  Current loss 1.1296370029449463
#
# Epoch number 86
#  Current loss 1.1207454204559326
#
# Epoch number 87
#  Current loss 1.0872414112091064
#
# Epoch number 88
#  Current loss 1.1599509716033936
#
# Epoch number 89
#  Current loss 1.1371784210205078
#
# Epoch number 90
#  Current loss 1.1078462600708008
#
# Epoch number 91
#  Current loss 1.223917841911316
#
# Epoch number 92
#  Current loss 1.2009252309799194
#
# Epoch number 93
#  Current loss 1.2400859594345093
#
# Epoch number 94
#  Current loss 1.2036998271942139
#
# Epoch number 95
#  Current loss 1.1540966033935547
#
# Epoch number 96
#  Current loss 1.2096290588378906
#
# Epoch number 97
#  Current loss 1.1049798727035522
#
# Epoch number 98
#  Current loss 1.1735848188400269
#
# Epoch number 99
#  Current loss 1.1578866243362427
#
# Epoch number 100
#  Current loss 1.05022394657135
#
# Epoch number 101
#  Current loss 1.1765036582946777
#
# Epoch number 102
#  Current loss 1.1134159564971924
#
# Epoch number 103
#  Current loss 1.1945381164550781
#
# Epoch number 104
#  Current loss 1.1667863130569458
#
# Epoch number 105
#  Current loss 1.1114730834960938
#
# Epoch number 106
#  Current loss 1.0902446508407593
#
# Epoch number 107
#  Current loss 1.1426998376846313
#
# Epoch number 108
#  Current loss 1.2086377143859863
#
# Epoch number 109
#  Current loss 1.1878187656402588
#
# Epoch number 110
#  Current loss 1.107492446899414
#
# Epoch number 111
#  Current loss 1.1757969856262207
#
# Epoch number 112
#  Current loss 1.1785839796066284
#
# Epoch number 113
#  Current loss 1.1288731098175049
#
# Epoch number 114
#  Current loss 1.0941827297210693
#
# Epoch number 115
#  Current loss 1.0684317350387573
#
# Epoch number 116
#  Current loss 1.0582090616226196
#
# Epoch number 117
#  Current loss 1.07566499710083
#
# Epoch number 118
#  Current loss 1.1765079498291016
#
# Epoch number 119
#  Current loss 1.1217962503433228
#
# Epoch number 120
#  Current loss 1.064121961593628
#
# Epoch number 121
#  Current loss 1.2054166793823242
#
# Epoch number 122
#  Current loss 1.074160099029541
#
# Epoch number 123
#  Current loss 1.0540212392807007
#
# Epoch number 124
#  Current loss 1.0992029905319214
#
# Epoch number 125
#  Current loss 1.1768550872802734
#
# Epoch number 126
#  Current loss 1.2058794498443604
#
# Epoch number 127
#  Current loss 1.1526904106140137
#
# Epoch number 128
#  Current loss 1.1678102016448975
#
# Epoch number 129
#  Current loss 1.1227784156799316
#
# Epoch number 130
#  Current loss 1.1043856143951416
#
# Epoch number 131
#  Current loss 1.1427910327911377
#
# Epoch number 132
#  Current loss 1.113671064376831
#
# Epoch number 133
#  Current loss 1.0563416481018066
#
# Epoch number 134
#  Current loss 1.1170241832733154
#
# Epoch number 135
#  Current loss 1.1482584476470947
#
# Epoch number 136
#  Current loss 1.0835647583007812
#
# Epoch number 137
#  Current loss 1.036800503730774
#
# Epoch number 138
#  Current loss 1.1448718309402466
#
# Epoch number 139
#  Current loss 1.0857760906219482
#
# Epoch number 140
#  Current loss 1.1154578924179077
#
# Epoch number 141
#  Current loss 1.0730059146881104
#
# Epoch number 142
#  Current loss 1.1207361221313477
#
# Epoch number 143
#  Current loss 1.078762412071228
#
# Epoch number 144
#  Current loss 1.1820112466812134
#
# Epoch number 145
#  Current loss 1.145541787147522
#
# Epoch number 146
#  Current loss 1.1117618083953857
#
# Epoch number 147
#  Current loss 1.098238229751587
#
# Epoch number 148
#  Current loss 1.1734035015106201
#
# Epoch number 149
#  Current loss 1.124728798866272
#
# Epoch number 150
#  Current loss 1.1668553352355957
#
# Epoch number 151
#  Current loss 1.0876777172088623
#
# Epoch number 152
#  Current loss 1.0681911706924438
#
# Epoch number 153
#  Current loss 1.1131420135498047
#
# Epoch number 154
#  Current loss 1.0854302644729614
#
# Epoch number 155
#  Current loss 1.0764631032943726
#
# Epoch number 156
#  Current loss 1.110447645187378
#
# Epoch number 157
#  Current loss 1.0780516862869263
#
# Epoch number 158
#  Current loss 1.063700556755066
#
# Epoch number 159
#  Current loss 1.2128078937530518
#
# Epoch number 160
#  Current loss 1.178700566291809
#
# Epoch number 161
#  Current loss 1.0161501169204712
#
# Epoch number 162
#  Current loss 1.0943634510040283
#
# Epoch number 163
#  Current loss 1.131976842880249
#
# Epoch number 164
#  Current loss 1.074561595916748
#
# Epoch number 165
#  Current loss 1.1509010791778564
#
# Epoch number 166
#  Current loss 1.1381611824035645
#
# Epoch number 167
#  Current loss 1.1513311862945557
#
# Epoch number 168
#  Current loss 1.122665524482727
#
# Epoch number 169
#  Current loss 1.234724521636963
#
# Epoch number 170
#  Current loss 1.1256591081619263
#
# Epoch number 171
#  Current loss 1.0714045763015747
#
# Epoch number 172
#  Current loss 1.1256356239318848
#
# Epoch number 173
#  Current loss 1.1961804628372192
#
# Epoch number 174
#  Current loss 1.1255643367767334
#
# Epoch number 175
#  Current loss 1.1028482913970947
#
# Epoch number 176
#  Current loss 1.035776138305664
#
# Epoch number 177
#  Current loss 1.1536086797714233
#
# Epoch number 178
#  Current loss 1.0926718711853027
#
# Epoch number 179
#  Current loss 1.1534470319747925
#
# Epoch number 180
#  Current loss 1.1026304960250854
#
# Epoch number 181
#  Current loss 1.1706150770187378
#
# Epoch number 182
#  Current loss 1.1366443634033203
#
# Epoch number 183
#  Current loss 1.182788372039795
#
# Epoch number 184
#  Current loss 1.0756101608276367
#
# Epoch number 185
#  Current loss 1.158249855041504
#
# Epoch number 186
#  Current loss 1.0751545429229736
#
# Epoch number 187
#  Current loss 1.1015362739562988
#
# Epoch number 188
#  Current loss 1.1015338897705078
#
# Epoch number 189
#  Current loss 1.1398310661315918
#
# Epoch number 190
#  Current loss 1.0567915439605713
#
# Epoch number 191
#  Current loss 1.067460536956787
#
# Epoch number 192
#  Current loss 1.0936591625213623
#
# Epoch number 193
#  Current loss 1.0686628818511963
#
# Epoch number 194
#  Current loss 1.072483777999878
#
# Epoch number 195
#  Current loss 1.0656983852386475
#
# Epoch number 196
#  Current loss 1.105344533920288
#
# Epoch number 197
#  Current loss 1.0260339975357056
#
# Epoch number 198
#  Current loss 1.0736806392669678
#
# Epoch number 199
#  Current loss 1.1261725425720215
#
# Epoch number 200
#  Current loss 1.1533325910568237
#
# Epoch number 201
#  Current loss 1.1210017204284668
#
# Epoch number 202
#  Current loss 1.0896066427230835
#
# Epoch number 203
#  Current loss 1.1172897815704346
#
# Epoch number 204
#  Current loss 1.1384320259094238
#
# Epoch number 205
#  Current loss 1.0410937070846558
#
# Epoch number 206
#  Current loss 0.9962275624275208
#
# Epoch number 207
#  Current loss 1.1538312435150146
#
# Epoch number 208
#  Current loss 1.0266863107681274
#
# Epoch number 209
#  Current loss 1.0474191904067993
#
# Epoch number 210
#  Current loss 1.098470687866211
#
# Epoch number 211
#  Current loss 1.1482505798339844
#
# Epoch number 212
#  Current loss 1.148913860321045
#
# Epoch number 213
#  Current loss 1.1212303638458252
#
# Epoch number 214
#  Current loss 1.1530787944793701
#
# Epoch number 215
#  Current loss 1.1020441055297852
#
# Epoch number 216
#  Current loss 1.094004511833191
#
# Epoch number 217
#  Current loss 1.197791576385498
#
# Epoch number 218
#  Current loss 1.130528211593628
#
# Epoch number 219
#  Current loss 1.1147342920303345
#
# Epoch number 220
#  Current loss 1.0892541408538818
#
# Epoch number 221
#  Current loss 1.1913628578186035
#
# Epoch number 222
#  Current loss 1.0083779096603394
#
# Epoch number 223
#  Current loss 1.1353044509887695
#
# Epoch number 224
#  Current loss 1.1839473247528076
#
# Epoch number 225
#  Current loss 1.0789613723754883
#
# Epoch number 226
#  Current loss 1.1501092910766602
#
# Epoch number 227
#  Current loss 1.0831315517425537
#
# Epoch number 228
#  Current loss 1.1719846725463867
#
# Epoch number 229
#  Current loss 1.0056957006454468
#
# Epoch number 230
#  Current loss 1.118310570716858
#
# Epoch number 231
#  Current loss 1.1208384037017822
#
# Epoch number 232
#  Current loss 1.1057679653167725
#
# Epoch number 233
#  Current loss 1.120055913925171
#
# Epoch number 234
#  Current loss 1.0476810932159424
#
# Epoch number 235
#  Current loss 1.0917527675628662
#
# Epoch number 236
#  Current loss 1.0727659463882446
#
# Epoch number 237
#  Current loss 1.0786570310592651
#
# Epoch number 238
#  Current loss 1.0557835102081299
#
# Epoch number 239
#  Current loss 1.0545427799224854
#
# Epoch number 240
#  Current loss 1.2082164287567139
#
# Epoch number 241
#  Current loss 1.1784762144088745
#
# Epoch number 242
#  Current loss 1.1652984619140625
#
# Epoch number 243
#  Current loss 1.1309113502502441
#
# Epoch number 244
#  Current loss 0.9924492835998535
#
# Epoch number 245
#  Current loss 1.1475498676300049
#
# Epoch number 246
#  Current loss 1.1418793201446533
#
# Epoch number 247
#  Current loss 1.1089900732040405
#
# Epoch number 248
#  Current loss 1.1025817394256592
#
# Epoch number 249
#  Current loss 0.965895414352417
#
# Epoch number 250
#  Current loss 1.081435203552246
#
# Epoch number 251
#  Current loss 1.1176860332489014
#
# Epoch number 252
#  Current loss 1.1118487119674683
#
# Epoch number 253
#  Current loss 1.15423583984375
#
# Epoch number 254
#  Current loss 1.1104676723480225
#
# Epoch number 255
#  Current loss 1.1289253234863281
#
# Epoch number 256
#  Current loss 1.1537466049194336
#
# Epoch number 257
#  Current loss 1.096869945526123
#
# Epoch number 258
#  Current loss 1.146155595779419
#
# Epoch number 259
#  Current loss 1.1000562906265259
#
# Epoch number 260
#  Current loss 1.2298448085784912
#
# Epoch number 261
#  Current loss 1.1844463348388672
#
# Epoch number 262
#  Current loss 1.006637692451477
#
# Epoch number 263
#  Current loss 1.1419334411621094
#
# Epoch number 264
#  Current loss 1.092846393585205
#
# Epoch number 265
#  Current loss 1.142203688621521
#
# Epoch number 266
#  Current loss 1.1752156019210815
#
# Epoch number 267
#  Current loss 1.166698932647705
#
# Epoch number 268
#  Current loss 1.0870380401611328
#
# Epoch number 269
#  Current loss 1.1003741025924683
#
# Epoch number 270
#  Current loss 1.083311915397644
#
# Epoch number 271
#  Current loss 1.0740182399749756
#
# Epoch number 272
#  Current loss 1.169236183166504
#
# Epoch number 273
#  Current loss 1.1066657304763794
#
# Epoch number 274
#  Current loss 1.1418216228485107
#
# Epoch number 275
#  Current loss 1.1291468143463135
#
# Epoch number 276
#  Current loss 1.0800474882125854
#
# Epoch number 277
#  Current loss 1.2111303806304932
#
# Epoch number 278
#  Current loss 1.1457539796829224
#
# Epoch number 279
#  Current loss 1.1091994047164917
#
# Epoch number 280
#  Current loss 1.221083164215088
#
# Epoch number 281
#  Current loss 1.108957290649414
#
# Epoch number 282
#  Current loss 1.0866999626159668
#
# Epoch number 283
#  Current loss 1.1542959213256836
#
# Epoch number 284
#  Current loss 1.1935679912567139
#
# Epoch number 285
#  Current loss 1.1187148094177246
#
# Epoch number 286
#  Current loss 1.1076987981796265
#
# Epoch number 287
#  Current loss 1.0990294218063354
#
# Epoch number 288
#  Current loss 1.0792920589447021
#
# Epoch number 289
#  Current loss 1.091728925704956
#
# Epoch number 290
#  Current loss 1.0847594738006592
#
# Epoch number 291
#  Current loss 1.0304336547851562
#
# Epoch number 292
#  Current loss 1.1481326818466187
#
# Epoch number 293
#  Current loss 1.1085801124572754
#
# Epoch number 294
#  Current loss 1.0488898754119873
#
# Epoch number 295
#  Current loss 1.092433214187622
#
# Epoch number 296
#  Current loss 1.1300029754638672
#
# Epoch number 297
#  Current loss 1.1004849672317505
#
# Epoch number 298
#  Current loss 1.107193112373352
#
# Epoch number 299
#  Current loss 1.1030219793319702
#
# Epoch number 300
#  Current loss 1.0848774909973145
#
# Epoch number 301
#  Current loss 1.1468936204910278
#
# Epoch number 302
#  Current loss 1.0546337366104126
#
# Epoch number 303
#  Current loss 1.1211670637130737
#
# Epoch number 304
#  Current loss 1.035179615020752
#
# Epoch number 305
#  Current loss 1.1866087913513184
#
# Epoch number 306
#  Current loss 1.0925910472869873
#
# Epoch number 307
#  Current loss 1.0972540378570557
#
# Epoch number 308
#  Current loss 1.0938258171081543
#
# Epoch number 309
#  Current loss 1.0949885845184326
#
# Epoch number 310
#  Current loss 1.124260663986206
#
# Epoch number 311
#  Current loss 1.103603482246399
#
# Epoch number 312
#  Current loss 1.1274120807647705
#
# Epoch number 313
#  Current loss 1.1545811891555786
#
# Epoch number 314
#  Current loss 1.1262319087982178
#
# Epoch number 315
#  Current loss 1.07682204246521
#
# Epoch number 316
#  Current loss 1.1332114934921265
#
# Epoch number 317
#  Current loss 1.1864358186721802
#
# Epoch number 318
#  Current loss 1.0559518337249756
#
# Epoch number 319
#  Current loss 1.19232177734375
#
# Epoch number 320
#  Current loss 1.1092034578323364
#
# Epoch number 321
#  Current loss 1.086287498474121
#
# Epoch number 322
#  Current loss 1.0991783142089844
#
# Epoch number 323
#  Current loss 1.0517045259475708
#
# Epoch number 324
#  Current loss 1.1692999601364136
#
# Epoch number 325
#  Current loss 1.1513618230819702
#
# Epoch number 326
#  Current loss 1.089531660079956
#
# Epoch number 327
#  Current loss 1.0963761806488037
#
# Epoch number 328
#  Current loss 1.0598361492156982
#
# Epoch number 329
#  Current loss 1.1745632886886597
#
# Epoch number 330
#  Current loss 1.1271966695785522
#
# Epoch number 331
#  Current loss 1.1478602886199951
#
# Epoch number 332
#  Current loss 1.1242039203643799
#
# Epoch number 333
#  Current loss 1.069252371788025
#
# Epoch number 334
#  Current loss 1.0873006582260132
#
# Epoch number 335
#  Current loss 1.0858173370361328
#
# Epoch number 336
#  Current loss 1.0912835597991943
#
# Epoch number 337
#  Current loss 1.1352885961532593
#
# Epoch number 338
#  Current loss 1.0720069408416748
#
# Epoch number 339
#  Current loss 1.1402992010116577
#
# Epoch number 340
#  Current loss 1.068938970565796
#
# Epoch number 341
#  Current loss 1.074917197227478
#
# Epoch number 342
#  Current loss 1.0812342166900635
#
# Epoch number 343
#  Current loss 1.0774781703948975
#
# Epoch number 344
#  Current loss 1.0903520584106445
#
# Epoch number 345
#  Current loss 1.1468554735183716
#
# Epoch number 346
#  Current loss 1.0627005100250244
#
# Epoch number 347
#  Current loss 1.089546799659729
#
# Epoch number 348
#  Current loss 1.1186814308166504
#
# Epoch number 349
#  Current loss 1.1376348733901978
#
# Epoch number 350
#  Current loss 1.074300765991211
#
# Epoch number 351
#  Current loss 1.1281498670578003
#
# Epoch number 352
#  Current loss 1.1271616220474243
#
# Epoch number 353
#  Current loss 1.096228837966919
#
# Epoch number 354
#  Current loss 1.0575367212295532
#
# Epoch number 355
#  Current loss 1.0725970268249512
#
# Epoch number 356
#  Current loss 1.010104775428772
#
# Epoch number 357
#  Current loss 1.0881365537643433
#
# Epoch number 358
#  Current loss 1.0978901386260986
#
# Epoch number 359
#  Current loss 1.054619550704956
#
# Epoch number 360
#  Current loss 1.0853861570358276
#
# Epoch number 361
#  Current loss 1.0851033926010132
#
# Epoch number 362
#  Current loss 1.17324960231781
#
# Epoch number 363
#  Current loss 1.0618358850479126
#
# Epoch number 364
#  Current loss 1.223692774772644
#
# Epoch number 365
#  Current loss 1.100816249847412
#
# Epoch number 366
#  Current loss 1.0966002941131592
#
# Epoch number 367
#  Current loss 1.1220009326934814
#
# Epoch number 368
#  Current loss 1.1894221305847168
#
# Epoch number 369
#  Current loss 1.1347033977508545
#
# Epoch number 370
#  Current loss 1.0520861148834229
#
# Epoch number 371
#  Current loss 1.079218864440918
#
# Epoch number 372
#  Current loss 1.1161707639694214
#
# Epoch number 373
#  Current loss 1.0638641119003296
#
# Epoch number 374
#  Current loss 1.1415071487426758
#
# Epoch number 375
#  Current loss 1.0988348722457886
#
# Epoch number 376
#  Current loss 1.096709132194519
#
# Epoch number 377
#  Current loss 1.109609603881836
#
# Epoch number 378
#  Current loss 1.1449618339538574
#
# Epoch number 379
#  Current loss 1.0860061645507812
#
# Epoch number 380
#  Current loss 1.0872159004211426
#
# Epoch number 381
#  Current loss 1.1808676719665527
#
# Epoch number 382
#  Current loss 1.0766981840133667
#
# Epoch number 383
#  Current loss 1.0304515361785889
#
# Epoch number 384
#  Current loss 1.1927233934402466
#
# Epoch number 385
#  Current loss 1.0433396100997925
#
# Epoch number 386
#  Current loss 1.0639253854751587
#
# Epoch number 387
#  Current loss 1.0754404067993164
#
# Epoch number 388
#  Current loss 1.1245553493499756
#
# Epoch number 389
#  Current loss 1.0670478343963623
#
# Epoch number 390
#  Current loss 1.0577467679977417
#
# Epoch number 391
#  Current loss 1.137534260749817
#
# Epoch number 392
#  Current loss 1.1352816820144653
#
# Epoch number 393
#  Current loss 1.1051956415176392
#
# Epoch number 394
#  Current loss 1.0807439088821411
#
# Epoch number 395
#  Current loss 1.138965368270874
#
# Epoch number 396
#  Current loss 1.1166930198669434
#
# Epoch number 397
#  Current loss 1.0291274785995483
#
# Epoch number 398
#  Current loss 1.068885087966919
#
# Epoch number 399
#  Current loss 1.1333086490631104
#
# Epoch number 400
#  Current loss 1.0619010925292969
#
# Epoch number 401
#  Current loss 1.0432833433151245
#
# Epoch number 402
#  Current loss 1.1824405193328857
#
# Epoch number 403
#  Current loss 1.0954720973968506
#
# Epoch number 404
#  Current loss 1.1622170209884644
#
# Epoch number 405
#  Current loss 1.0515284538269043
#
# Epoch number 406
#  Current loss 1.0455405712127686
#
# Epoch number 407
#  Current loss 1.1482089757919312
#
# Epoch number 408
#  Current loss 1.0994954109191895
#
# Epoch number 409
#  Current loss 1.0777899026870728
#
# Epoch number 410
#  Current loss 1.1101335287094116
#
# Epoch number 411
#  Current loss 1.0502110719680786
#
# Epoch number 412
#  Current loss 1.0637321472167969
#
# Epoch number 413
#  Current loss 1.1499528884887695
#
# Epoch number 414
#  Current loss 1.0320770740509033
#
# Epoch number 415
#  Current loss 1.0847479104995728
#
# Epoch number 416
#  Current loss 0.9930747151374817
#
# Epoch number 417
#  Current loss 1.072359561920166
#
# Epoch number 418
#  Current loss 1.0547094345092773
#
# Epoch number 419
#  Current loss 1.1316478252410889
#
# Epoch number 420
#  Current loss 1.1075305938720703
#
# Epoch number 421
#  Current loss 1.1054751873016357
#
# Epoch number 422
#  Current loss 1.059324026107788
#
# Epoch number 423
#  Current loss 1.0524107217788696
#
# Epoch number 424
#  Current loss 1.0266733169555664
#
# Epoch number 425
#  Current loss 1.113282561302185
#
# Epoch number 426
#  Current loss 1.1091361045837402
#
# Epoch number 427
#  Current loss 1.0836594104766846
#
# Epoch number 428
#  Current loss 1.1243863105773926
#
# Epoch number 429
#  Current loss 1.161008358001709
#
# Epoch number 430
#  Current loss 1.0871766805648804
#
# Epoch number 431
#  Current loss 1.046320915222168
#
# Epoch number 432
#  Current loss 1.0892146825790405
#
# Epoch number 433
#  Current loss 1.1197463274002075
#
# Epoch number 434
#  Current loss 1.0632245540618896
#
# Epoch number 435
#  Current loss 1.0906940698623657
#
# Epoch number 436
#  Current loss 1.0467314720153809
#
# Epoch number 437
#  Current loss 1.0933340787887573
#
# Epoch number 438
#  Current loss 1.022848129272461
#
# Epoch number 439
#  Current loss 1.0416096448898315
#
# Epoch number 440
#  Current loss 1.0517103672027588
#
# Epoch number 441
#  Current loss 1.1669201850891113
#
# Epoch number 442
#  Current loss 1.03110671043396
#
# Epoch number 443
#  Current loss 1.0167393684387207
#
# Epoch number 444
#  Current loss 1.0614066123962402
#
# Epoch number 445
#  Current loss 1.0530864000320435
#
# Epoch number 446
#  Current loss 1.1207762956619263
#
# Epoch number 447
#  Current loss 1.1486657857894897
#
# Epoch number 448
#  Current loss 1.0194485187530518
#
# Epoch number 449
#  Current loss 1.0548250675201416
#
# Epoch number 450
#  Current loss 1.0072212219238281
#
# Epoch number 451
#  Current loss 1.092806339263916
#
# Epoch number 452
#  Current loss 1.036767601966858
#
# Epoch number 453
#  Current loss 1.0958718061447144
#
# Epoch number 454
#  Current loss 1.0255718231201172
#
# Epoch number 455
#  Current loss 1.1497414112091064
#
# Epoch number 456
#  Current loss 1.023672103881836
#
# Epoch number 457
#  Current loss 1.0581800937652588
#
# Epoch number 458
#  Current loss 1.0809962749481201
#
# Epoch number 459
#  Current loss 1.0612562894821167
#
# Epoch number 460
#  Current loss 1.0769834518432617
#
# Epoch number 461
#  Current loss 1.0824553966522217
#
# Epoch number 462
#  Current loss 1.0577235221862793
#
# Epoch number 463
#  Current loss 1.1366244554519653
#
# Epoch number 464
#  Current loss 1.1315499544143677
#
# Epoch number 465
#  Current loss 1.0597630739212036
#
# Epoch number 466
#  Current loss 1.0654988288879395
#
# Epoch number 467
#  Current loss 1.090436339378357
#
# Epoch number 468
#  Current loss 1.1248416900634766
#
# Epoch number 469
#  Current loss 1.1218204498291016
#
# Epoch number 470
#  Current loss 1.1560673713684082
#
# Epoch number 471
#  Current loss 1.0517756938934326
#
# Epoch number 472
#  Current loss 1.0990110635757446
#
# Epoch number 473
#  Current loss 1.1314680576324463
#
# Epoch number 474
#  Current loss 1.068599820137024
#
# Epoch number 475
#  Current loss 1.1130186319351196
#
# Epoch number 476
#  Current loss 1.1273304224014282
#
# Epoch number 477
#  Current loss 1.0617932081222534
#
# Epoch number 478
#  Current loss 1.1593610048294067
#
# Epoch number 479
#  Current loss 1.0569473505020142
#
# Epoch number 480
#  Current loss 1.0254125595092773
#
# Epoch number 481
#  Current loss 1.1444005966186523
#
# Epoch number 482
#  Current loss 1.1228861808776855
#
# Epoch number 483
#  Current loss 1.0871667861938477
#
# Epoch number 484
#  Current loss 1.0762653350830078
#
# Epoch number 485
#  Current loss 1.0992380380630493
#
# Epoch number 486
#  Current loss 1.11652410030365
#
# Epoch number 487
#  Current loss 1.139952301979065
#
# Epoch number 488
#  Current loss 1.0760784149169922
#
# Epoch number 489
#  Current loss 1.0723603963851929
#
# Epoch number 490
#  Current loss 1.1172351837158203
#
# Epoch number 491
#  Current loss 1.0705881118774414
#
# Epoch number 492
#  Current loss 1.0815455913543701
#
# Epoch number 493
#  Current loss 1.0446054935455322
#
# Epoch number 494
#  Current loss 1.0717120170593262
#
# Epoch number 495
#  Current loss 1.1120942831039429
#
# Epoch number 496
#  Current loss 1.0603888034820557
#
# Epoch number 497
#  Current loss 1.098818302154541
#
# Epoch number 498
#  Current loss 1.019252061843872
#
# Epoch number 499
#  Current loss 1.0649402141571045

# %% [markdown]
# ## Some simple testing
#
# Subject 4 was held out from the training, and will be used to test. The Distance between each image pair denotes the degree of similarity the model found between the two images. Less means it found more similar, while higher values indicate it found them to be dissimilar.
#
# A genuine image on the left is held fixed and is compared with same, genuine, forged, and different signature.
#
# Same: 1
#
# Genuine : 7
#
# Forged: 3,4,5,9,10
#
# Different : 2,6,8

# %%
folder_dataset_test = dset.ImageFolder(root=Config.testing_dir)
siamese_dataset = SiameseNetworkDataset(imageFolderDataset=folder_dataset_test,
                                        transform=transforms.Compose([transforms.Resize((100,100)),
                                                                      transforms.ToTensor()
                                                                      ])
                                       ,should_invert=False)

test_dataloader = DataLoader(siamese_dataset,num_workers=6,batch_size=1,shuffle=True)
dataiter = iter(test_dataloader)
x0,_,_ = next(dataiter)

for i in range(10):
    _,x1,label2 = next(dataiter)
    concatenated = torch.cat((x0,x1),0)
    
    output1,output2 = net(Variable(x0).cuda(),Variable(x1).cuda())
    euclidean_distance = F.pairwise_distance(output1, output2)
    imshow(torchvision.utils.make_grid(concatenated),'Dissimilarity: {:.2f}'.format(euclidean_distance.item()))

# %% [markdown]
# **In conclusion, promising results have been obtained by training a relatively smaller network on only sample dataset provided by the organizers and no additional dataset or the extra dataset provided in the phase two had been used.   This proves the versatility of the Siamese Neural Network for the task of one-shot learning with relatively smaller dataset.**
