# %% [markdown]
# ## Installing PyTorch and Pillow == 0.4

# %%
from os import path
from wheel.pep425tags import get_abbr_impl, get_impl_ver, get_abi_tag
platform = '{}{}-{}'.format(get_abbr_impl(), get_impl_ver(), get_abi_tag())

accelerator = 'cu80' if path.exists('/opt/bin/nvidia-smi') else 'cpu'

# !pip install -q http://download.pytorch.org/whl/{accelerator}/torch-0.4.0-{platform}-linux_x86_64.whl torchvision
import torch
print(torch.__version__)
print(torch.cuda.is_available())
# Out:
# 0.4.0
# True

# %%
# !pip install Pillow==4.0.0
# Out:
# Collecting Pillow==4.0.0
#   Using cached https://files.pythonhosted.org/packages/37/e8/b3fbf87b0188d22246678f8cd61e23e31caa1769ebc06f1664e2e5fe8a17/Pillow-4.0.0-cp36-cp36m-manylinux1_x86_64.whl
# Requirement already satisfied: olefile in /usr/local/lib/python3.6/dist-packages (from Pillow==4.0.0) (0.46)
# torchvision 0.2.1 has requirement pillow>=4.1.1, but you'll have pillow 4.0.0 which is incompatible.
# Installing collected packages: Pillow
#   Found existing installation: Pillow 5.3.0
#     Uninstalling Pillow-5.3.0:
#       Successfully uninstalled Pillow-5.3.0
# Successfully installed Pillow-4.0.0

# %% [markdown]
# ## Imports
# All the imports are defined here

# %%
# %matplotlib inline
import os
import torchvision
import torchvision.datasets as dset
import torchvision.transforms as transforms
from torch.utils.data import DataLoader,Dataset
import matplotlib.pyplot as plt
import torchvision.utils
import numpy as np
import random
from PIL import Image
import torch
from torch.autograd import Variable
import PIL.ImageOps    
import torch.nn as nn
from torch import optim
import torch.nn.functional as F

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
# !ls '/content/drive/My Drive/Colab Notebooks/axis_data/processed_dataset'
# Out:
# final_backup_saved_model.pt  forged  saved_model.pt  testing  training

# %% [markdown]
# ## Helper functions
# Set of helper functions

# %%
def imshow(img,text=None,should_save=False):
    npimg = img.numpy()
    plt.axis("off")
    if text:
        plt.text(75, 8, text, style='italic',fontweight='bold',
            bbox={'facecolor':'white', 'alpha':0.8, 'pad':10})
    plt.imshow(np.transpose(npimg, (1, 2, 0)))
    plt.show()    

def show_plot(iteration,loss):
    plt.plot(iteration,loss)
    plt.show()

# %% [markdown]
# ## Configuration Class
# A simple class to manage configuration

# %%
class Config():
    training_dir = "/content/drive/My Drive/Colab Notebooks/axis_data/processed_dataset/training/"
    testing_dir = "/content/drive/My Drive/Colab Notebooks/axis_data/processed_dataset/testing/"
    train_batch_size = 64
    train_number_epochs = 500

# %% [markdown]
# #### Class Mapping

# %%
def find_classes(dir):
    classes = os.listdir(dir)
    classes.sort()
    class_to_idx = {classes[i]: i for i in range(len(classes))}
    return classes, class_to_idx
  
find_classes(Config.training_dir)[1]
# Out:
# {'002': 0,
#  '003': 1,
#  '004': 2,
#  '005': 3,
#  '006': 4,
#  '007': 5,
#  '008': 6,
#  '009': 7,
#  '010': 8,
#  '011': 9,
#  '012': 10,
#  '013': 11,
#  '014': 12,
#  '015': 13,
#  '016': 14,
#  '017': 15,
#  '018': 16,
#  '019': 17,
#  '020': 18,
#  '021': 19,
#  '022': 20,
#  '023': 21,
#  '024': 22,
#  '025': 23,
#  '026': 24,
#  '027': 25,
#  '028': 26,
#  '029': 27,
#  '030': 28,
#  'f02': 29,
#  'f03': 30,
#  'f04': 31,
#  'f05': 32,
#  'f06': 33,
#  'f07': 34,
#  'f08': 35,
#  'f09': 36,
#  'f10': 37,
#  'f11': 38,
#  'f12': 39,
#  'f13': 40,
#  'f14': 41,
#  'f15': 42,
#  'f16': 43,
#  'f17': 44,
#  'f18': 45,
#  'f19': 46,
#  'f20': 47,
#  'f21': 48,
#  'f22': 49,
#  'f23': 50,
#  'f24': 51,
#  'f25': 52,
#  'f26': 53,
#  'f27': 54,
#  'f28': 55,
#  'f29': 56,
#  'f30': 57}

# %% [markdown]
# ## Custom Dataset Class
# This dataset generates a pair of images. 0 for geniune pair and 1 for imposter pair

# %%
class SiameseNetworkDataset(Dataset):
    
    def __init__(self,imageFolderDataset,transform=None,should_invert=True):
        self.imageFolderDataset = imageFolderDataset    
        self.transform = transform
        self.should_invert = should_invert
        
    def __getitem__(self,index):
        img0_tuple = random.choice([item for item in self.imageFolderDataset.imgs if item[1] < 29]) #Considering only genuine images for perfect pair
        #we need to make sure approx 50% of images are in the same class
        should_get_same_class = random.randint(0,1)
        if should_get_same_class:
          while True:
            img1_tuple = random.choice(self.imageFolderDataset.imgs)
            if img0_tuple[1]==img1_tuple[1]:
              break

        else:
          img1_tuple = random.choice([item for item in self.imageFolderDataset.imgs if item[1] == (img0_tuple[1] + 29)]) # Considering a pair of fake + genuine of same person's signature

        img0 = Image.open(img0_tuple[0])
        img1 = Image.open(img1_tuple[0])
        img0 = img0.convert("L")
        img1 = img1.convert("L")
        
        if self.should_invert:
            img0 = PIL.ImageOps.invert(img0)
            img1 = PIL.ImageOps.invert(img1)

        if self.transform is not None:
            img0 = self.transform(img0)
            img1 = self.transform(img1)
        
        return img0, img1 , torch.from_numpy(np.array([int(img1_tuple[1]!=img0_tuple[1])],dtype=np.float32))
    
    def __len__(self):
        return len(self.imageFolderDataset.imgs)

# %% [markdown]
# ## Using Image Folder Dataset

# %%
folder_dataset = dset.ImageFolder(root=Config.training_dir)

# %%
siamese_dataset = SiameseNetworkDataset(imageFolderDataset=folder_dataset,
                                        transform=transforms.Compose([transforms.Resize((100,100)),
                                                                      transforms.ToTensor()
                                                                      ])
                                       ,should_invert=False)

# %% [markdown]
# ## Visualising some of the data
# The top row and the bottom row of any column is one pair. The 0s and 1s correspond to the column of the image. 1 indiciates dissimilar, and 0 indicates similar.

# %%
vis_dataloader = DataLoader(siamese_dataset,
                        shuffle=True,
                        num_workers=16,
                        batch_size=8)
dataiter = iter(vis_dataloader)


example_batch = next(dataiter)
concatenated = torch.cat((example_batch[0],example_batch[1]),0)
imshow(torchvision.utils.make_grid(concatenated))
print(example_batch[2].numpy())
# Out:
# [[1.]
#  [0.]
#  [0.]
#  [0.]
#  [1.]
#  [1.]
#  [0.]
#  [1.]]

# %% [markdown]
# ## Neural Net Definition
# We will use a standard convolutional neural network
#
# Its architecture might look like below,
#
# ![](https://res.mdpi.com/symmetry/symmetry-10-00385/article_deploy/html/images/symmetry-10-00385-g001.png)

# %%
class SiameseNetwork(nn.Module):
    def __init__(self):
        super(SiameseNetwork, self).__init__()
        self.cnn1 = nn.Sequential(
            nn.ReflectionPad2d(1),
            nn.Conv2d(1, 128, kernel_size=3),
            nn.ReLU(inplace=True),
            nn.BatchNorm2d(128),
            
            nn.ReflectionPad2d(1),
            nn.Conv2d(128, 64, kernel_size=3),
            nn.ReLU(inplace=True),
            nn.BatchNorm2d(64),
            
            nn.ReflectionPad2d(1),
            nn.Conv2d(64, 32, kernel_size=3),
            nn.ReLU(inplace=True),
            nn.BatchNorm2d(32),

            nn.ReflectionPad2d(1),
            nn.Conv2d(32, 16, kernel_size=3),
            nn.ReLU(inplace=True),
            nn.BatchNorm2d(16),
            
            nn.ReflectionPad2d(1),
            nn.Conv2d(16, 8, kernel_size=3),
            nn.ReLU(inplace=True),
            nn.BatchNorm2d(8),


        )

        self.fc1 = nn.Sequential(
            nn.Linear(8*100*100, 500),
            nn.ReLU(inplace=True),

            nn.Linear(500, 500),
            nn.ReLU(inplace=True),

            nn.Linear(500, 5))

    def forward_once(self, x):
        output = self.cnn1(x)
        output = output.view(output.size()[0], -1)
        output = self.fc1(output)
        return output

    def forward(self, input1, input2):
        output1 = self.forward_once(input1)
        output2 = self.forward_once(input2)
        return output1, output2

# %% [markdown]
# ## Contrastive Loss

# %%
class ContrastiveLoss(torch.nn.Module):
    """
    Contrastive loss function.
    Based on: http://yann.lecun.com/exdb/publis/pdf/hadsell-chopra-lecun-06.pdf
    """

    def __init__(self, margin=2.0):
        super(ContrastiveLoss, self).__init__()
        self.margin = margin

    def forward(self, output1, output2, label):
        euclidean_distance = F.pairwise_distance(output1, output2)
        loss_contrastive = torch.mean((1-label) * torch.pow(euclidean_distance, 2) +
                                      (label) * torch.pow(torch.clamp(self.margin - euclidean_distance, min=0.0), 2))


        return loss_contrastive

# %% [markdown]
# ## Training Time!

# %%
train_dataloader = DataLoader(siamese_dataset,
                        shuffle=True,
                        num_workers=8,
                        batch_size=Config.train_batch_size)

# %%
net = SiameseNetwork().cuda()
criterion = ContrastiveLoss()
optimizer = optim.Adam(net.parameters(),lr = 0.001)

# %%
counter = []
loss_history = [] 
iteration_number= 0

# %%
for epoch in range(0,Config.train_number_epochs):
    for i, data in enumerate(train_dataloader,0):
        img0, img1 , label = data
        img0, img1 , label = img0.cuda(), img1.cuda() , label.cuda()
        optimizer.zero_grad()
        output1,output2 = net(img0,img1)
        loss_contrastive = criterion(output1,output2,label)
        loss_contrastive.backward()
        optimizer.step()
        if i %10 == 0 :
            print("Epoch number {}\n Current loss {}\n".format(epoch,loss_contrastive.item()))
            iteration_number +=10
            counter.append(iteration_number)
            loss_history.append(loss_contrastive.item())
show_plot(counter,loss_history)
# Out:
# Epoch number 0
#  Current loss 1.8109614849090576
#
# Epoch number 1
#  Current loss 1.5440655946731567
#
# Epoch number 2
#  Current loss 2.1521615982055664
#
# Epoch number 3
#  Current loss 2.0588455200195312
#
# Epoch number 4
#  Current loss 1.3572226762771606
#
# Epoch number 5
#  Current loss 1.874342918395996
#
# Epoch number 6
#  Current loss 1.3507118225097656
#
# Epoch number 7
#  Current loss 1.265768051147461
#
# Epoch number 8
#  Current loss 1.2848572731018066
#
# Epoch number 9
#  Current loss 1.1789915561676025
#
# Epoch number 10
#  Current loss 1.1863210201263428
#
# Epoch number 11
#  Current loss 1.073771357536316
#
# Epoch number 12
#  Current loss 1.279421091079712
#
# Epoch number 13
#  Current loss 1.233760118484497
#
# Epoch number 14
#  Current loss 1.2051177024841309
#
# Epoch number 15
#  Current loss 1.1479220390319824
#
# Epoch number 16
#  Current loss 1.1647999286651611
#
# Epoch number 17
#  Current loss 1.1932158470153809
#
# Epoch number 18
#  Current loss 1.4844595193862915
#
# Epoch number 19
#  Current loss 1.492672324180603
#
# Epoch number 20
#  Current loss 1.087355375289917
#
# Epoch number 21
#  Current loss 3.088818073272705
#
# Epoch number 22
#  Current loss 1.237658143043518
#
# Epoch number 23
#  Current loss 1.235747218132019
#
# Epoch number 24
#  Current loss 1.283132791519165
#
# Epoch number 25
#  Current loss 1.2138607501983643
#
# Epoch number 26
#  Current loss 1.187042236328125
#
# Epoch number 27
#  Current loss 1.2147468328475952
#
# Epoch number 28
#  Current loss 1.3195619583129883
#
# Epoch number 29
#  Current loss 1.1674525737762451
#
# Epoch number 30
#  Current loss 1.2045001983642578
#
# Epoch number 31
#  Current loss 1.2084718942642212
#
# Epoch number 32
#  Current loss 1.1856619119644165
#
# Epoch number 33
#  Current loss 1.1910748481750488
#
# Epoch number 34
#  Current loss 1.1830545663833618
#
# Epoch number 35
#  Current loss 1.1645793914794922
#
# Epoch number 36
#  Current loss 1.121548056602478
#
# Epoch number 37
#  Current loss 1.1491057872772217
#
# Epoch number 38
#  Current loss 1.1495378017425537
#
# Epoch number 39
#  Current loss 1.1346046924591064
#
# Epoch number 40
#  Current loss 1.1461035013198853
#
# Epoch number 41
#  Current loss 1.1153743267059326
#
# Epoch number 42
#  Current loss 1.151426076889038
#
# Epoch number 43
#  Current loss 1.1595920324325562
#
# Epoch number 44
#  Current loss 1.1921238899230957
#
# Epoch number 45
#  Current loss 1.1017581224441528
#
# Epoch number 46
#  Current loss 1.1315816640853882
#
# Epoch number 47
#  Current loss 1.0960469245910645
#
# Epoch number 48
#  Current loss 1.0809543132781982
#
# Epoch number 49
#  Current loss 1.1122504472732544
#
# Epoch number 50
#  Current loss 1.139971137046814
#
# Epoch number 51
#  Current loss 1.156638503074646
#
# Epoch number 52
#  Current loss 1.0893075466156006
#
# Epoch number 53
#  Current loss 1.1229383945465088
#
# Epoch number 54
#  Current loss 1.064721941947937
#
# Epoch number 55
#  Current loss 1.0870898962020874
#
# Epoch number 56
#  Current loss 1.108640432357788
#
# Epoch number 57
#  Current loss 0.9534241557121277
#
# Epoch number 58
#  Current loss 1.0812721252441406
#
# Epoch number 59
#  Current loss 1.1063721179962158
#
# Epoch number 60
#  Current loss 1.119208812713623
#
# Epoch number 61
#  Current loss 1.0288313627243042
#
# Epoch number 62
#  Current loss 1.0738941431045532
#
# Epoch number 63
#  Current loss 1.136824607849121
#
# Epoch number 64
#  Current loss 1.0795317888259888
#
# Epoch number 65
#  Current loss 1.0523232221603394
#
# Epoch number 66
#  Current loss 1.0834596157073975
#
# Epoch number 67
#  Current loss 1.0649217367172241
#
# Epoch number 68
#  Current loss 1.1005275249481201
#
# Epoch number 69
#  Current loss 1.0831189155578613
#
# Epoch number 70
#  Current loss 1.111689567565918
#
# Epoch number 71
#  Current loss 1.0452041625976562
#
# Epoch number 72
#  Current loss 1.0535123348236084
#
# Epoch number 73
#  Current loss 1.1164991855621338
#
# Epoch number 74
#  Current loss 1.0768264532089233
#
# Epoch number 75
#  Current loss 1.0688376426696777
#
# Epoch number 76
#  Current loss 1.0962841510772705
#
# Epoch number 77
#  Current loss 1.0684858560562134
#
# Epoch number 78
#  Current loss 1.0610467195510864
#
# Epoch number 79
#  Current loss 1.0880955457687378
#
# Epoch number 80
#  Current loss 1.0500141382217407
#
# Epoch number 81
#  Current loss 1.0363759994506836
#
# Epoch number 82
#  Current loss 1.1058976650238037
#
# Epoch number 83
#  Current loss 1.1783862113952637
#
# Epoch number 84
#  Current loss 1.1994006633758545
#
# Epoch number 85
#  Current loss 1.1136233806610107
#
# Epoch number 86
#  Current loss 1.1572599411010742
#
# Epoch number 87
#  Current loss 1.1479432582855225
#
# Epoch number 88
#  Current loss 1.1538074016571045
#
# Epoch number 89
#  Current loss 1.1277551651000977
#
# Epoch number 90
#  Current loss 1.1049377918243408
#
# Epoch number 91
#  Current loss 1.0942257642745972
#
# Epoch number 92
#  Current loss 1.1177486181259155
#
# Epoch number 93
#  Current loss 1.12328040599823
#
# Epoch number 94
#  Current loss 1.0949493646621704
#
# Epoch number 95
#  Current loss 1.1411364078521729
#
# Epoch number 96
#  Current loss 1.180686593055725
#
# Epoch number 97
#  Current loss 1.0941081047058105
#
# Epoch number 98
#  Current loss 1.0907318592071533
#
# Epoch number 99
#  Current loss 1.192748785018921
#
# Epoch number 100
#  Current loss 1.0981829166412354
#
# Epoch number 101
#  Current loss 1.080812692642212
#
# Epoch number 102
#  Current loss 1.087976336479187
#
# Epoch number 103
#  Current loss 1.0797010660171509
#
# Epoch number 104
#  Current loss 1.3365297317504883
#
# Epoch number 105
#  Current loss 1.1241912841796875
#
# Epoch number 106
#  Current loss 1.1086570024490356
#
# Epoch number 107
#  Current loss 1.1965241432189941
#
# Epoch number 108
#  Current loss 1.1381078958511353
#
# Epoch number 109
#  Current loss 1.097585916519165
#
# Epoch number 110
#  Current loss 1.0599324703216553
#
# Epoch number 111
#  Current loss 1.139169692993164
#
# Epoch number 112
#  Current loss 1.1153559684753418
#
# Epoch number 113
#  Current loss 1.0692182779312134
#
# Epoch number 114
#  Current loss 1.0882295370101929
#
# Epoch number 115
#  Current loss 1.0199693441390991
#
# Epoch number 116
#  Current loss 1.0637925863265991
#
# Epoch number 117
#  Current loss 1.1774640083312988
#
# Epoch number 118
#  Current loss 1.0890265703201294
#
# Epoch number 119
#  Current loss 1.0926367044448853
#
# Epoch number 120
#  Current loss 1.109852910041809
#
# Epoch number 121
#  Current loss 1.0449761152267456
#
# Epoch number 122
#  Current loss 1.0646803379058838
#
# Epoch number 123
#  Current loss 1.0651017427444458
#
# Epoch number 124
#  Current loss 1.076013445854187
#
# Epoch number 125
#  Current loss 1.0680361986160278
#
# Epoch number 126
#  Current loss 1.162125587463379
#
# Epoch number 127
#  Current loss 1.117787480354309
#
# Epoch number 128
#  Current loss 1.1840342283248901
#
# Epoch number 129
#  Current loss 1.0807019472122192
#
# Epoch number 130
#  Current loss 1.0515220165252686
#
# Epoch number 131
#  Current loss 1.068650245666504
#
# Epoch number 132
#  Current loss 1.1130385398864746
#
# Epoch number 133
#  Current loss 1.0399470329284668
#
# Epoch number 134
#  Current loss 1.0753923654556274
#
# Epoch number 135
#  Current loss 1.0250961780548096
#
# Epoch number 136
#  Current loss 1.035108208656311
#
# Epoch number 137
#  Current loss 1.0461152791976929
#
# Epoch number 138
#  Current loss 1.0711214542388916
#
# Epoch number 139
#  Current loss 1.0501364469528198
#
# Epoch number 140
#  Current loss 1.0884499549865723
#
# Epoch number 141
#  Current loss 1.0771541595458984
#
# Epoch number 142
#  Current loss 1.0737773180007935
#
# Epoch number 143
#  Current loss 1.0402495861053467
#
# Epoch number 144
#  Current loss 1.0413188934326172
#
# Epoch number 145
#  Current loss 1.1187169551849365
#
# Epoch number 146
#  Current loss 1.0477668046951294
#
# Epoch number 147
#  Current loss 1.0410892963409424
#
# Epoch number 148
#  Current loss 1.0510379076004028
#
# Epoch number 149
#  Current loss 1.0650756359100342
#
# Epoch number 150
#  Current loss 1.099021553993225
#
# Epoch number 151
#  Current loss 1.0708930492401123
#
# Epoch number 152
#  Current loss 1.0708160400390625
#
# Epoch number 153
#  Current loss 1.0589325428009033
#
# Epoch number 154
#  Current loss 1.073329210281372
#
# Epoch number 155
#  Current loss 1.041045904159546
#
# Epoch number 156
#  Current loss 1.0698992013931274
#
# Epoch number 157
#  Current loss 1.0540143251419067
#
# Epoch number 158
#  Current loss 1.0481582880020142
#
# Epoch number 159
#  Current loss 1.0953079462051392
#
# Epoch number 160
#  Current loss 1.0377187728881836
#
# Epoch number 161
#  Current loss 1.071474313735962
#
# Epoch number 162
#  Current loss 1.0589048862457275
#
# Epoch number 163
#  Current loss 1.1073497533798218
#
# Epoch number 164
#  Current loss 1.0880215167999268
#
# Epoch number 165
#  Current loss 1.0355033874511719
#
# Epoch number 166
#  Current loss 1.036027193069458
#
# Epoch number 167
#  Current loss 0.9874317646026611
#
# Epoch number 168
#  Current loss 1.0433549880981445
#
# Epoch number 169
#  Current loss 1.0460352897644043
#
# Epoch number 170
#  Current loss 1.0910489559173584
#
# Epoch number 171
#  Current loss 1.0871405601501465
#
# Epoch number 172
#  Current loss 0.9825493693351746
#
# Epoch number 173
#  Current loss 1.1158126592636108
#
# Epoch number 174
#  Current loss 1.0756146907806396
#
# Epoch number 175
#  Current loss 1.0696425437927246
#
# Epoch number 176
#  Current loss 1.0616391897201538
#
# Epoch number 177
#  Current loss 1.1137051582336426
#
# Epoch number 178
#  Current loss 1.0522680282592773
#
# Epoch number 179
#  Current loss 1.0060853958129883
#
# Epoch number 180
#  Current loss 1.046983003616333
#
# Epoch number 181
#  Current loss 1.0728535652160645
#
# Epoch number 182
#  Current loss 1.1455104351043701
#
# Epoch number 183
#  Current loss 1.0333383083343506
#
# Epoch number 184
#  Current loss 1.0701576471328735
#
# Epoch number 185
#  Current loss 1.0259006023406982
#
# Epoch number 186
#  Current loss 1.0657657384872437
#
# Epoch number 187
#  Current loss 1.0331006050109863
#
# Epoch number 188
#  Current loss 1.1078451871871948
#
# Epoch number 189
#  Current loss 1.0955746173858643
#
# Epoch number 190
#  Current loss 1.079857349395752
#
# Epoch number 191
#  Current loss 1.0812275409698486
#
# Epoch number 192
#  Current loss 1.1219196319580078
#
# Epoch number 193
#  Current loss 1.0946753025054932
#
# Epoch number 194
#  Current loss 0.9152721166610718
#
# Epoch number 195
#  Current loss 1.0489758253097534
#
# Epoch number 196
#  Current loss 1.0350594520568848
#
# Epoch number 197
#  Current loss 1.05294668674469
#
# Epoch number 198
#  Current loss 1.0546119213104248
#
# Epoch number 199
#  Current loss 1.047698974609375
#
# Epoch number 200
#  Current loss 1.0342854261398315
#
# Epoch number 201
#  Current loss 1.037935495376587
#
# Epoch number 202
#  Current loss 1.0350053310394287
#
# Epoch number 203
#  Current loss 1.0598664283752441
#
# Epoch number 204
#  Current loss 1.0216741561889648
#
# Epoch number 205
#  Current loss 1.0442017316818237
#
# Epoch number 206
#  Current loss 0.9674798250198364
#
# Epoch number 207
#  Current loss 1.0612455606460571
#
# Epoch number 208
#  Current loss 1.0286047458648682
#
# Epoch number 209
#  Current loss 1.0286812782287598
#
# Epoch number 210
#  Current loss 1.0260581970214844
#
# Epoch number 211
#  Current loss 1.044003963470459
#
# Epoch number 212
#  Current loss 0.9911298155784607
#
# Epoch number 213
#  Current loss 1.0995715856552124
#
# Epoch number 214
#  Current loss 1.0649482011795044
#
# Epoch number 215
#  Current loss 0.9879181385040283
#
# Epoch number 216
#  Current loss 1.0445444583892822
#
# Epoch number 217
#  Current loss 1.040178894996643
#
# Epoch number 218
#  Current loss 1.060915231704712
#
# Epoch number 219
#  Current loss 1.0290520191192627
#
# Epoch number 220
#  Current loss 1.046179175376892
#
# Epoch number 221
#  Current loss 1.0542850494384766
#
# Epoch number 222
#  Current loss 1.1145875453948975
#
# Epoch number 223
#  Current loss 1.032071828842163
#
# Epoch number 224
#  Current loss 0.8978102207183838
#
# Epoch number 225
#  Current loss 1.041076421737671
#
# Epoch number 226
#  Current loss 1.103822112083435
#
# Epoch number 227
#  Current loss 1.0456626415252686
#
# Epoch number 228
#  Current loss 0.8920286893844604
#
# Epoch number 229
#  Current loss 1.0523751974105835
#
# Epoch number 230
#  Current loss 1.0256564617156982
#
# Epoch number 231
#  Current loss 1.0194324254989624
#
# Epoch number 232
#  Current loss 1.0526014566421509
#
# Epoch number 233
#  Current loss 1.0489075183868408
#
# Epoch number 234
#  Current loss 1.0239969491958618
#
# Epoch number 235
#  Current loss 1.0475863218307495
#
# Epoch number 236
#  Current loss 1.0103744268417358
#
# Epoch number 237
#  Current loss 1.0217392444610596
#
# Epoch number 238
#  Current loss 1.0914169549942017
#
# Epoch number 239
#  Current loss 1.0490328073501587
#
# Epoch number 240
#  Current loss 1.024428129196167
#
# Epoch number 241
#  Current loss 1.0402960777282715
#
# Epoch number 242
#  Current loss 1.0215325355529785
#
# Epoch number 243
#  Current loss 1.0711686611175537
#
# Epoch number 244
#  Current loss 1.0388542413711548
#
# Epoch number 245
#  Current loss 1.0243169069290161
#
# Epoch number 246
#  Current loss 1.0528573989868164
#
# Epoch number 247
#  Current loss 1.0273081064224243
#
# Epoch number 248
#  Current loss 1.0383424758911133
#
# Epoch number 249
#  Current loss 1.027057409286499
#
# Epoch number 250
#  Current loss 1.045201063156128
#
# Epoch number 251
#  Current loss 1.047608494758606
#
# Epoch number 252
#  Current loss 1.018495798110962
#
# Epoch number 253
#  Current loss 1.0383518934249878
#
# Epoch number 254
#  Current loss 1.023091435432434
#
# Epoch number 255
#  Current loss 1.0659570693969727
#
# Epoch number 256
#  Current loss 1.0409778356552124
#
# Epoch number 257
#  Current loss 1.0387580394744873
#
# Epoch number 258
#  Current loss 1.0252172946929932
#
# Epoch number 259
#  Current loss 1.0404844284057617
#
# Epoch number 260
#  Current loss 1.0209846496582031
#
# Epoch number 261
#  Current loss 1.031006097793579
#
# Epoch number 262
#  Current loss 1.0160388946533203
#
# Epoch number 263
#  Current loss 1.0731931924819946
#
# Epoch number 264
#  Current loss 1.1089036464691162
#
# Epoch number 265
#  Current loss 1.0628983974456787
#
# Epoch number 266
#  Current loss 1.0544593334197998
#
# Epoch number 267
#  Current loss 1.0062041282653809
#
# Epoch number 268
#  Current loss 1.041426658630371
#
# Epoch number 269
#  Current loss 1.0431432723999023
#
# Epoch number 270
#  Current loss 1.0242329835891724
#
# Epoch number 271
#  Current loss 1.0493979454040527
#
# Epoch number 272
#  Current loss 1.0092498064041138
#
# Epoch number 273
#  Current loss 1.0321788787841797
#
# Epoch number 274
#  Current loss 1.0219024419784546
#
# Epoch number 275
#  Current loss 1.015904426574707
#
# Epoch number 276
#  Current loss 1.022223949432373
#
# Epoch number 277
#  Current loss 1.0083125829696655
#
# Epoch number 278
#  Current loss 1.0284032821655273
#
# Epoch number 279
#  Current loss 1.030960202217102
#
# Epoch number 280
#  Current loss 1.0184595584869385
#
# Epoch number 281
#  Current loss 1.009030818939209
#
# Epoch number 282
#  Current loss 1.0126054286956787
#
# Epoch number 283
#  Current loss 1.010813593864441
#
# Epoch number 284
#  Current loss 1.022680640220642
#
# Epoch number 285
#  Current loss 1.025404691696167
#
# Epoch number 286
#  Current loss 1.0481711626052856
#
# Epoch number 287
#  Current loss 1.0255401134490967
#
# Epoch number 288
#  Current loss 1.0335357189178467
#
# Epoch number 289
#  Current loss 1.0158554315567017
#
# Epoch number 290
#  Current loss 1.0387462377548218
#
# Epoch number 291
#  Current loss 1.1362495422363281
#
# Epoch number 292
#  Current loss 1.0147109031677246
#
# Epoch number 293
#  Current loss 1.036642074584961
#
# Epoch number 294
#  Current loss 1.0016705989837646
#
# Epoch number 295
#  Current loss 1.0113894939422607
#
# Epoch number 296
#  Current loss 1.0095975399017334
#
# Epoch number 297
#  Current loss 1.029117226600647
#
# Epoch number 298
#  Current loss 1.0467778444290161
#
# Epoch number 299
#  Current loss 1.0956671237945557
#
# Epoch number 300
#  Current loss 1.004168152809143
#
# Epoch number 301
#  Current loss 1.013202428817749
#
# Epoch number 302
#  Current loss 1.059738278388977
#
# Epoch number 303
#  Current loss 1.0538480281829834
#
# Epoch number 304
#  Current loss 1.0161457061767578
#
# Epoch number 305
#  Current loss 1.0638525485992432
#
# Epoch number 306
#  Current loss 1.0432868003845215
#
# Epoch number 307
#  Current loss 1.1009310483932495
#
# Epoch number 308
#  Current loss 1.0446046590805054
#
# Epoch number 309
#  Current loss 1.0480821132659912
#
# Epoch number 310
#  Current loss 1.035417079925537
#
# Epoch number 311
#  Current loss 1.022553563117981
#
# Epoch number 312
#  Current loss 1.07578706741333
#
# Epoch number 313
#  Current loss 1.025599479675293
#
# Epoch number 314
#  Current loss 1.0477895736694336
#
# Epoch number 315
#  Current loss 1.0117871761322021
#
# Epoch number 316
#  Current loss 0.8562729358673096
#
# Epoch number 317
#  Current loss 1.011989951133728
#
# Epoch number 318
#  Current loss 1.01511549949646
#
# Epoch number 319
#  Current loss 1.0283355712890625
#
# Epoch number 320
#  Current loss 1.004727840423584
#
# Epoch number 321
#  Current loss 1.028491735458374
#
# Epoch number 322
#  Current loss 1.0371509790420532
#
# Epoch number 323
#  Current loss 1.0323671102523804
#
# Epoch number 324
#  Current loss 1.0191195011138916
#
# Epoch number 325
#  Current loss 1.0158088207244873
#
# Epoch number 326
#  Current loss 1.0246829986572266
#
# Epoch number 327
#  Current loss 1.023071527481079
#
# Epoch number 328
#  Current loss 1.030102014541626
#
# Epoch number 329
#  Current loss 1.0246444940567017
#
# Epoch number 330
#  Current loss 1.0402849912643433
#
# Epoch number 331
#  Current loss 1.0294654369354248
#
# Epoch number 332
#  Current loss 1.0200841426849365
#
# Epoch number 333
#  Current loss 1.0140190124511719
#
# Epoch number 334
#  Current loss 1.0066978931427002
#
# Epoch number 335
#  Current loss 1.0286612510681152
#
# Epoch number 336
#  Current loss 1.0656358003616333
#
# Epoch number 337
#  Current loss 1.0169885158538818
#
# Epoch number 338
#  Current loss 1.0613795518875122
#
# Epoch number 339
#  Current loss 1.0714192390441895
#
# Epoch number 340
#  Current loss 1.0263550281524658
#
# Epoch number 341
#  Current loss 1.0090880393981934
#
# Epoch number 342
#  Current loss 1.0511592626571655
#
# Epoch number 343
#  Current loss 1.0802221298217773
#
# Epoch number 344
#  Current loss 1.0285402536392212
#
# Epoch number 345
#  Current loss 1.0193724632263184
#
# Epoch number 346
#  Current loss 0.99906325340271
#
# Epoch number 347
#  Current loss 1.0171129703521729
#
# Epoch number 348
#  Current loss 1.0081226825714111
#
# Epoch number 349
#  Current loss 1.016017198562622
#
# Epoch number 350
#  Current loss 1.0022624731063843
#
# Epoch number 351
#  Current loss 1.0067737102508545
#
# Epoch number 352
#  Current loss 1.1152433156967163
#
# Epoch number 353
#  Current loss 1.0278195142745972
#
# Epoch number 354
#  Current loss 1.0764766931533813
#
# Epoch number 355
#  Current loss 1.0451087951660156
#
# Epoch number 356
#  Current loss 1.0183682441711426
#
# Epoch number 357
#  Current loss 0.8758348226547241
#
# Epoch number 358
#  Current loss 1.0642375946044922
#
# Epoch number 359
#  Current loss 1.0290541648864746
#
# Epoch number 360
#  Current loss 1.0301482677459717
#
# Epoch number 361
#  Current loss 1.0110254287719727
#
# Epoch number 362
#  Current loss 1.029970645904541
#
# Epoch number 363
#  Current loss 1.166149377822876
#
# Epoch number 364
#  Current loss 1.01759934425354
#
# Epoch number 365
#  Current loss 0.9926061630249023
#
# Epoch number 366
#  Current loss 1.0350064039230347
#
# Epoch number 367
#  Current loss 1.0295697450637817
#
# Epoch number 368
#  Current loss 1.0363268852233887
#
# Epoch number 369
#  Current loss 1.0571353435516357
#
# Epoch number 370
#  Current loss 1.0082086324691772
#
# Epoch number 371
#  Current loss 1.0307682752609253
#
# Epoch number 372
#  Current loss 1.0460853576660156
#
# Epoch number 373
#  Current loss 1.006645679473877
#
# Epoch number 374
#  Current loss 1.0128096342086792
#
# Epoch number 375
#  Current loss 0.9986008405685425
#
# Epoch number 376
#  Current loss 1.0241062641143799
#
# Epoch number 377
#  Current loss 1.0237605571746826
#
# Epoch number 378
#  Current loss 1.0018701553344727
#
# Epoch number 379
#  Current loss 0.9627804756164551
#
# Epoch number 380
#  Current loss 0.9973158240318298
#
# Epoch number 381
#  Current loss 1.013716459274292
#
# Epoch number 382
#  Current loss 1.0590965747833252
#
# Epoch number 383
#  Current loss 1.1317083835601807
#
# Epoch number 384
#  Current loss 1.0364729166030884
#
# Epoch number 385
#  Current loss 1.0041773319244385
#
# Epoch number 386
#  Current loss 1.0445126295089722
#
# Epoch number 387
#  Current loss 1.0736896991729736
#
# Epoch number 388
#  Current loss 1.0317397117614746
#
# Epoch number 389
#  Current loss 1.0230448246002197
#
# Epoch number 390
#  Current loss 1.0272753238677979
#
# Epoch number 391
#  Current loss 1.0260999202728271
#
# Epoch number 392
#  Current loss 1.0185964107513428
#
# Epoch number 393
#  Current loss 1.0140643119812012
#
# Epoch number 394
#  Current loss 1.0123223066329956
#
# Epoch number 395
#  Current loss 1.0200542211532593
#
# Epoch number 396
#  Current loss 1.0137394666671753
#
# Epoch number 397
#  Current loss 1.0285924673080444
#
# Epoch number 398
#  Current loss 1.038775086402893
#
# Epoch number 399
#  Current loss 1.0282745361328125
#
# Epoch number 400
#  Current loss 1.030355453491211
#
# Epoch number 401
#  Current loss 1.0295599699020386
#
# Epoch number 402
#  Current loss 1.0116082429885864
#
# Epoch number 403
#  Current loss 1.0231971740722656
#
# Epoch number 404
#  Current loss 1.0034242868423462
#
# Epoch number 405
#  Current loss 1.028735637664795
#
# Epoch number 406
#  Current loss 1.033521056175232
#
# Epoch number 407
#  Current loss 1.0066059827804565
#
# Epoch number 408
#  Current loss 1.0061392784118652
#
# Epoch number 409
#  Current loss 1.028896450996399
#
# Epoch number 410
#  Current loss 0.9973427653312683
#
# Epoch number 411
#  Current loss 1.0215002298355103
#
# Epoch number 412
#  Current loss 1.012472152709961
#
# Epoch number 413
#  Current loss 1.025634765625
#
# Epoch number 414
#  Current loss 1.0216848850250244
#
# Epoch number 415
#  Current loss 1.0250418186187744
#
# Epoch number 416
#  Current loss 0.9736829996109009
#
# Epoch number 417
#  Current loss 1.0269842147827148
#
# Epoch number 418
#  Current loss 1.0077242851257324
#
# Epoch number 419
#  Current loss 1.0199952125549316
#
# Epoch number 420
#  Current loss 1.016106128692627
#
# Epoch number 421
#  Current loss 1.031675934791565
#
# Epoch number 422
#  Current loss 1.0178468227386475
#
# Epoch number 423
#  Current loss 1.0022180080413818
#
# Epoch number 424
#  Current loss 1.0376026630401611
#
# Epoch number 425
#  Current loss 1.012945294380188
#
# Epoch number 426
#  Current loss 1.0202518701553345
#
# Epoch number 427
#  Current loss 1.0224158763885498
#
# Epoch number 428
#  Current loss 1.0161352157592773
#
# Epoch number 429
#  Current loss 1.0381304025650024
#
# Epoch number 430
#  Current loss 1.0213384628295898
#
# Epoch number 431
#  Current loss 1.0101025104522705
#
# Epoch number 432
#  Current loss 1.018176794052124
#
# Epoch number 433
#  Current loss 1.0401711463928223
#
# Epoch number 434
#  Current loss 1.0077061653137207
#
# Epoch number 435
#  Current loss 1.0030492544174194
#
# Epoch number 436
#  Current loss 1.0138561725616455
#
# Epoch number 437
#  Current loss 1.016477346420288
#
# Epoch number 438
#  Current loss 1.0000197887420654
#
# Epoch number 439
#  Current loss 1.0319876670837402
#
# Epoch number 440
#  Current loss 1.0072582960128784
#
# Epoch number 441
#  Current loss 0.9022895097732544
#
# Epoch number 442
#  Current loss 1.0067806243896484
#
# Epoch number 443
#  Current loss 0.9916726350784302
#
# Epoch number 444
#  Current loss 1.0151584148406982
#
# Epoch number 445
#  Current loss 0.9857160449028015
#
# Epoch number 446
#  Current loss 1.0109612941741943
#
# Epoch number 447
#  Current loss 1.026557207107544
#
# Epoch number 448
#  Current loss 1.0047004222869873
#
# Epoch number 449
#  Current loss 0.9974639415740967
#
# Epoch number 450
#  Current loss 1.0206884145736694
#
# Epoch number 451
#  Current loss 1.0220438241958618
#
# Epoch number 452
#  Current loss 1.024168848991394
#
# Epoch number 453
#  Current loss 0.9755634069442749
#
# Epoch number 454
#  Current loss 1.0108835697174072
#
# Epoch number 455
#  Current loss 1.011620283126831
#
# Epoch number 456
#  Current loss 0.9673093557357788
#
# Epoch number 457
#  Current loss 1.0174281597137451
#
# Epoch number 458
#  Current loss 1.0182045698165894
#
# Epoch number 459
#  Current loss 1.0065178871154785
#
# Epoch number 460
#  Current loss 1.0202250480651855
#
# Epoch number 461
#  Current loss 0.8463412523269653
#
# Epoch number 462
#  Current loss 1.0111768245697021
#
# Epoch number 463
#  Current loss 1.0334675312042236
#
# Epoch number 464
#  Current loss 0.9929907321929932
#
# Epoch number 465
#  Current loss 1.021124005317688
#
# Epoch number 466
#  Current loss 1.0023702383041382
#
# Epoch number 467
#  Current loss 0.9978234767913818
#
# Epoch number 468
#  Current loss 0.9841495156288147
#
# Epoch number 469
#  Current loss 1.030149221420288
#
# Epoch number 470
#  Current loss 1.0032161474227905
#
# Epoch number 471
#  Current loss 1.0177459716796875
#
# Epoch number 472
#  Current loss 1.0339183807373047
#
# Epoch number 473
#  Current loss 1.0099706649780273
#
# Epoch number 474
#  Current loss 1.0397659540176392
#
# Epoch number 475
#  Current loss 1.0207264423370361
#
# Epoch number 476
#  Current loss 1.0128147602081299
#
# Epoch number 477
#  Current loss 1.0179334878921509
#
# Epoch number 478
#  Current loss 1.0411533117294312
#
# Epoch number 479
#  Current loss 1.007163643836975
#
# Epoch number 480
#  Current loss 1.0228255987167358
#
# Epoch number 481
#  Current loss 1.036005973815918
#
# Epoch number 482
#  Current loss 1.041483998298645
#
# Epoch number 483
#  Current loss 1.0486721992492676
#
# Epoch number 484
#  Current loss 1.0157561302185059
#
# Epoch number 485
#  Current loss 0.9917102456092834
#
# Epoch number 486
#  Current loss 1.033636450767517
#
# Epoch number 487
#  Current loss 1.0320879220962524
#
# Epoch number 488
#  Current loss 0.9810697436332703
#
# Epoch number 489
#  Current loss 1.0221675634384155
#
# Epoch number 490
#  Current loss 1.0137039422988892
#
# Epoch number 491
#  Current loss 1.0208823680877686
#
# Epoch number 492
#  Current loss 1.0212140083312988
#
# Epoch number 493
#  Current loss 1.019099235534668
#
# Epoch number 494
#  Current loss 0.8473234176635742
#
# Epoch number 495
#  Current loss 1.0282659530639648
#
# Epoch number 496
#  Current loss 1.017137885093689
#
# Epoch number 497
#  Current loss 1.0295778512954712
#
# Epoch number 498
#  Current loss 1.0192081928253174
#
# Epoch number 499
#  Current loss 1.0046310424804688

# %%
# torch.save(net,"/content/drive/My Drive/Colab Notebooks/axis_data/processed_dataset/saved_model.pt")
# net = torch.load("/content/drive/My Drive/Colab Notebooks/axis_data/processed_dataset/saved_model.pt")

# filepath = "/content/drive/My Drive/Colab Notebooks/axis_data/processed_dataset/final_backup_saved_model.pt" # 0.76 threshold

filepath = "/content/drive/My Drive/Colab Notebooks/axis_data/processed_dataset/modified_data_loader_saved_model.pt"

torch.save(net.state_dict(), filepath)

#Later to restore:
net.load_state_dict(torch.load(filepath))

# %%
# !ls '/content/drive/My Drive/Colab Notebooks/axis_data/processed_dataset/'
# Out:
# final_backup_saved_model.pt  modified_data_loader_saved_model.pt  testing
# forged			     saved_model.pt			  training

# %%
class InferenceSiameseNetworkDataset(Dataset):
    
    def __init__(self,imageFolderDataset,transform=None,should_invert=True):
        self.imageFolderDataset = imageFolderDataset    
        self.transform = transform
        self.should_invert = should_invert
        
    def __getitem__(self,index):
        img0_tuple = random.choice(self.imageFolderDataset.imgs)
        #we need to make sure approx 50% of images are in the same class
        should_get_same_class = random.randint(0,1) 
        if should_get_same_class:
            while True:
                #keep looping till the same class image is found
                img1_tuple = random.choice(self.imageFolderDataset.imgs) 
                if img0_tuple[1]==img1_tuple[1]:
                    break
        else:
            while True:
                #keep looping till a different class image is found
                
                img1_tuple = random.choice(self.imageFolderDataset.imgs) 
                if img0_tuple[1] !=img1_tuple[1]:
                    break

        img0 = Image.open(img0_tuple[0])
        img1 = Image.open(img1_tuple[0])
        img0 = img0.convert("L")
        img1 = img1.convert("L")
        
        if self.should_invert:
            img0 = PIL.ImageOps.invert(img0)
            img1 = PIL.ImageOps.invert(img1)

        if self.transform is not None:
            img0 = self.transform(img0)
            img1 = self.transform(img1)
        
        return img0, img1 , torch.from_numpy(np.array([int(img1_tuple[1]!=img0_tuple[1])],dtype=np.float32))
    
    def __len__(self):
        return len(self.imageFolderDataset.imgs)

# %% [markdown]
# ## Some simple testing
#
# Subject 4 was held out from the training, and will be used to test. The Distance between each image pair denotes the degree of similarity the model found between the two images. Less means it found more similar, while higher values indicate it found them to be dissimilar.
#
# A genuine image on the left is held fixed and is compared with genuine, forged, and different signature.
#
# Genuine : 6,10
#
# Forged: 1,5,7,9
#
# Different : 2,3,4,8

# %%
folder_dataset_test = dset.ImageFolder(root=Config.testing_dir)
siamese_dataset = InferenceSiameseNetworkDataset(imageFolderDataset=folder_dataset_test,
                                        transform=transforms.Compose([transforms.Resize((100,100)),
                                                                      transforms.ToTensor()
                                                                      ])
                                       ,should_invert=False)

test_dataloader = DataLoader(siamese_dataset,num_workers=6,batch_size=1,shuffle=True)
dataiter = iter(test_dataloader)
x0,_,_ = next(dataiter)

for i in range(10):
    _,x1,label2 = next(dataiter)
    concatenated = torch.cat((x0,x1),0)
    
    output1,output2 = net(Variable(x0).cuda(),Variable(x1).cuda())
    euclidean_distance = F.pairwise_distance(output1, output2)
    imshow(torchvision.utils.make_grid(concatenated),'Dissimilarity: {:.2f}'.format(euclidean_distance.item()))

# %% [markdown]
# **In conclusion, promising results have been obtained by training a relatively smaller network on only sample dataset provided by the organizers and no additional dataset or the extra dataset provided in the phase two had been used.   This proves the versatility of the Siamese Neural Network for the task of one-shot learning with relatively smaller dataset.**
